# %% [markdown]
# # Customer Segmentation and PCA- t-SNE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import plot
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %% [markdown]
# # Before we begin;
# * If you like my work, please upvote this kernel because it will motivated me for more research and work. # Introduction;
# * Firstly we will explore the dataset and we will make some visualizations.
# * We will create a new dataset which is about rfm analysis. With the dataset we are going to segment the customers with some properties.
# * We will use the Kmeans algorithm and several dimensionality reduction techniques.

# %%
data = pd.read_csv('sales_data_sample.csv', encoding = 'unicode_escape')
print("data shape is:", data.shape, "*"*50)
data.head(3)
# Out:
# data shape is: (2823, 25) **************************************************
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
#
#         ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  2/24/2003 0:00  Shipped       1         2     2003  ...
# 1   5/7/2003 0:00  Shipped       2         5     2003  ...
# 2   7/1/2003 0:00  Shipped       3         7     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue           NaN    NYC    NY      10022
# 1             59 rue de l'Abbaye           NaN  Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia           NaN  Paris   NaN      75508
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0     USA       NaN              Yu             Kwai    Small
# 1  France      EMEA         Henriot             Paul    Small
# 2  France      EMEA        Da Cunha           Daniel   Medium
#
# [3 rows x 25 columns]

# %%
describe = data.describe().T
describe.style.background_gradient(cmap = "Oranges")
# Out:
# <style  type="text/css" >
#     #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col1 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col2 {
#             background-color:  #ffefe0;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col3 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col4 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col5 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col6 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row0_col7 {
#             background-color:  #db4a02;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col2 {
#             background-color:  #fff5ea;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col4 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col5 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col6 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row1_col7 {
#             background-color:  #fff5ea;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col1 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col2 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col4 {
#             background-color:  #fff5ea;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col5 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col6 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row2_col7 {
#             background-color:  #fff5ea;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col4 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col5 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col6 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row3_col7 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col1 {
#             background-color:  #fdb678;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col2 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col3 {
#             background-color:  #ffefe0;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col4 {
#             background-color:  #fdd6ae;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col5 {
#             background-color:  #fdc088;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col6 {
#             background-color:  #fd9e54;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row4_col7 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col4 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col5 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col6 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row5_col7 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col4 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col5 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col6 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row6_col7 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row7_col0 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row7_col1 {
#             background-color:  #fddab6;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row7_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_bdeba7a4_8b40_11ec_bf28_086266b8e515row7_col3 {
#             background-color:  #fdd9b5;
#             color:  #000000;

# %%
columns  = data.columns
nunique = pd.DataFrame(data[columns].nunique())
nunique.style.background_gradient(cmap="afmhot")
# Out:
# <style  type="text/css" >
#     #T_be393f99_8b40_11ec_bb4b_086266b8e515row0_col0 {
#             background-color:  #380000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row1_col0 {
#             background-color:  #0a0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row2_col0 {
#             background-color:  #ba3a00;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row3_col0 {
#             background-color:  #020000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row4_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row5_col0 {
#             background-color:  #2e0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row6_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row7_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row8_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row9_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row10_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row11_col0 {
#             background-color:  #0e0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row12_col0 {
#             background-color:  #120000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row13_col0 {
#             background-color:  #100000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row14_col0 {
#             background-color:  #100000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row15_col0 {
#             background-color:  #100000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row16_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row17_col0 {
#             background-color:  #0c0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row18_col0 {
#             background-color:  #020000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row19_col0 {
#             background-color:  #0c0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row20_col0 {
#             background-color:  #020000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row21_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row22_col0 {
#             background-color:  #0c0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row23_col0 {
#             background-color:  #0c0000;
#             color:  #f1f1f1;
#         }    #T_be393f99_8b40_11ec_bb4b_086266b8e515row24_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_be393f99_8b40_11ec_bb4b_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row0" class="row_heading level0 row0" >ORDERNUMBER</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row0_col0" class="data row0 col0" >307</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row1" class="row_heading level0 row1" >QUANTITYORDERED</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row1_col0" class="data row1 col0" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row2" class="row_heading level0 row2" >PRICEEACH</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row2_col0" class="data row2 col0" >1016</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row3" class="row_heading level0 row3" >ORDERLINENUMBER</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row3_col0" class="data row3 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row4" class="row_heading level0 row4" >SALES</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row4_col0" class="data row4 col0" >2763</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row5" class="row_heading level0 row5" >ORDERDATE</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row5_col0" class="data row5 col0" >252</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row6" class="row_heading level0 row6" >STATUS</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row6_col0" class="data row6 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row7" class="row_heading level0 row7" >QTR_ID</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row7_col0" class="data row7 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row8" class="row_heading level0 row8" >MONTH_ID</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row8_col0" class="data row8 col0" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row9" class="row_heading level0 row9" >YEAR_ID</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row9_col0" class="data row9 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row10" class="row_heading level0 row10" >PRODUCTLINE</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row10_col0" class="data row10 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row11" class="row_heading level0 row11" >MSRP</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row11_col0" class="data row11 col0" >80</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row12" class="row_heading level0 row12" >PRODUCTCODE</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row12_col0" class="data row12 col0" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row13" class="row_heading level0 row13" >CUSTOMERNAME</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row13_col0" class="data row13 col0" >92</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row14" class="row_heading level0 row14" >PHONE</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row14_col0" class="data row14 col0" >91</td>
#             </tr>
#             <tr>
#                         <th id="T_be393f99_8b40_11ec_bb4b_086266b8e515level0_row15" class="row_heading level0 row15" >ADDRESSLINE1</th>
#                         <td id="T_be393f99_8b40_11ec_bb4b_086266b8e515row15_col0

# %% [markdown]
# # FOR RFM ANALYSIS
# 1. "SALES" column is for "monetory"
# 2. "ORDERDATE" column is for "recency"
# 3. "QUANTITYORDERED" column is for "frequency"

# %%
print("Total Missing Values Numbers of columns;")
isnull = pd.DataFrame(data.isnull().sum())
isnull.style.background_gradient(cmap="ocean")
# Out:
# Total Missing Values Numbers of columns;
# <style  type="text/css" >
#     #T_beb4785f_8b40_11ec_ae9f_086266b8e515row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row5_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row6_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row7_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row8_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row9_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row10_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row11_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row12_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row13_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row14_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row15_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row16_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row17_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row18_col0 {
#             background-color:  #006296;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row19_col0 {
#             background-color:  #007507;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row20_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row21_col0 {
#             background-color:  #00246d;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row22_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row23_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_beb4785f_8b40_11ec_ae9f_086266b8e515row24_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }</style><table id="T_beb4785f_8b40_11ec_ae9f_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row0" class="row_heading level0 row0" >ORDERNUMBER</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row1" class="row_heading level0 row1" >QUANTITYORDERED</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row1_col0" class="data row1 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row2" class="row_heading level0 row2" >PRICEEACH</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row2_col0" class="data row2 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row3" class="row_heading level0 row3" >ORDERLINENUMBER</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row3_col0" class="data row3 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row4" class="row_heading level0 row4" >SALES</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row4_col0" class="data row4 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row5" class="row_heading level0 row5" >ORDERDATE</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row5_col0" class="data row5 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row6" class="row_heading level0 row6" >STATUS</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row6_col0" class="data row6 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row7" class="row_heading level0 row7" >QTR_ID</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row7_col0" class="data row7 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row8" class="row_heading level0 row8" >MONTH_ID</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row8_col0" class="data row8 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row9" class="row_heading level0 row9" >YEAR_ID</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row9_col0" class="data row9 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row10" class="row_heading level0 row10" >PRODUCTLINE</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row10_col0" class="data row10 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row11" class="row_heading level0 row11" >MSRP</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row11_col0" class="data row11 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row12" class="row_heading level0 row12" >PRODUCTCODE</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row12_col0" class="data row12 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row13" class="row_heading level0 row13" >CUSTOMERNAME</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row13_col0" class="data row13 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row14" class="row_heading level0 row14" >PHONE</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row14_col0" class="data row14 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_beb4785f_8b40_11ec_ae9f_086266b8e515level0_row15" class="row_heading level0 row15" >ADDRESSLINE1</th>
#                         <td id="T_beb4785f_8b40_11ec_ae9f_086266b8e515row15_col0" class="data row1

# %%
fig = px.pie(data, names='COUNTRY', title='Country Pie Chart')
fig.show()
# Out:
# <div>                            <div id="aef60f89-52ff-4852-9136-3792f8851ae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aef60f89-52ff-4852-9136-3792f8851ae0")) {                    Plotly.newPlot(                        "aef60f89-52ff-4852-9136-3792f8851ae0",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "COUNTRY=%{label}<extra></extra>", "labels": ["USA", "France", "France", "USA", "USA", "USA", "France", "Norway", "USA", "France", "Australia", "USA", "USA", "USA", "France", "USA", "Finland", "Norway", "USA", "USA", "Austria", "Australia", "France", "USA", "UK", "Spain", "Norway", "Sweden", "Spain", "USA", "Singapore", "USA", "Australia", "USA", "France", "Canada", "USA", "USA", "USA", "Japan", "Australia", "Italy", "Sweden", "France", "USA", "USA", "USA", "Australia", "USA", "USA", "USA", "Australia", "Canada", "Spain", "USA", "Australia", "France", "USA", "USA", "USA", "France", "Norway", "USA", "Japan", "Australia", "USA", "USA", "USA", "France", "USA", "France", "USA", "USA", "USA", "Japan", "Australia", "Australia", "USA", "France", "Spain", "USA", "Australia", "France", "USA", "USA", "USA", "France", "Norway", "USA", "Japan", "Australia", "USA", "USA", "USA", "France", "USA", "Finland", "USA", "USA", "USA", "Japan", "USA", "Australia", "USA", "UK", "Spain", "Denmark", "Austria", "UK", "USA", "Finland", "Sweden", "France", "UK", "Spain", "USA", "USA", "USA", "Canada", "Belgium", "Canada", "USA", "USA", "UK", "Norway", "USA", "Spain", "France", "Finland", "USA", "France", "USA", "USA", "Norway", "France", "Spain", "USA", "Singapore", "Austria", "UK", "USA", "France", "USA", "Singapore", "USA", "USA", "Singapore", "Australia", "USA", "Sweden", "USA", "Canada", "USA", "Sweden", "Australia", "USA", "Australia", "USA", "Australia", "Canada", "France", "Philippines", "France", "USA", "USA", "USA", "Australia", "Norway", "Germany", "Spain", "France", "Switzerland", "Denmark", "UK", "Italy", "USA", "Switzerland", "Germany", "Germany", "Sweden", "USA", "Austria", "Finland", "France", "Sweden", "Austria", "Denmark", "Singapore", "USA", "USA", "Spain", "Singapore", "Italy", "USA", "USA", "France", "Ireland", "Spain", "Finland", "USA", "USA", "Italy", "UK", "Denmark", "Norway", "France", "Spain", "France", "USA", "USA", "France", "USA", "Norway", "USA", "Spain", "USA", "Singapore", "Austria", "Australia", "USA", "France", "Canada", "France", "USA", "USA", "Japan", "Australia", "USA", "Sweden", "France", "Canada", "USA", "USA", "Australia", "USA", "Australia", "USA", "Australia", "Canada", "Spain", "USA", "France", "France", "USA", "USA", "Australia", "France", "USA", "USA", "France", "France", "USA", "USA", "USA", "USA", "USA", "Finland", "Norway", "USA", "USA", "Austria", "USA", "France", "USA", "UK", "Spain", "Spain", "Singapore", "USA", "USA", "Spain", "Singapore", "Italy", "USA", "USA", "France", "Ireland", "Germany", "Finland", "USA", "USA", "Italy", "UK", "Denmark", "USA", "France", "Spain", "Spain", "Japan", "USA", "USA", "Philippines", "France", "USA", "USA", "USA", "Austria", "Norway", "Germany", "Spain", "Spain", "Switzerland", "Denmark", "UK", "Italy", "USA", "Switzerland", "Germany", "Germany", "Sweden", "USA", "Austria", "Finland", "USA", "Sweden", "Austria", "Denmark", "Singapore", "USA", "USA", "Spain", "Singapore", "Italy", "USA", "USA", "France", "Ireland", "Spain", "Finland", "USA", "USA", "Italy", "UK", "Denmark", "Norway", "France", "USA", "France", "Japan", "USA", "USA", "USA", "Philippines", "France", "USA", "USA", "USA", "Australia", "Norway", "Germany", "Spain", "France", "Switzerland", "Denmark", "UK", "Italy", "USA", "Switzerland", "Germany", "Germany", "Sweden", "USA", "Austria", "Finland", "Finland", "Sweden", "Austria",  ...

# %%
# boş değere sahip olan 3 kolon için herhangi bir işlem yapmayacağım. Oranları çok fazla ve bu projenin ana odağı değil. 
# Ancak ilerideki PCA tekniği için missing value'larda kurtulmam gerek
addresline2_missing_value_rates = data["ADDRESSLINE2"].isnull().sum() * 100 / len(data)
state_missing_value_rates = data["STATE"].isnull().sum() * 100 / len(data)
terrıtory_missing_value_rates = data["TERRITORY"].isnull().sum() * 100 / len(data)
print("ADDRESSLINE2 missing value rates % : ",round(addresline2_missing_value_rates,3))
print("STATE missing value rates % : ",round(state_missing_value_rates,3))
print("TERRITORY missing value rates % : ",round(terrıtory_missing_value_rates,3))

data = data.drop(["ADDRESSLINE2","STATE","TERRITORY"], axis=1)
# Out:
# ADDRESSLINE2 missing value rates % :  89.302
# STATE missing value rates % :  52.639
# TERRITORY missing value rates % :  38.045

# %% [markdown]
# * Burada bir kaç kolonumuzun eksik veriye sahip olduğunu görebiliriz. Ancak bu kolonlar RFM analizi veya kümeleme için önemli olan kolonlardan değil bu yüzden bu adımları atlayıp konumuza geri dönelim.
# * recency yani zamanlama, yenilik kavramını sağlamak için tarih ile ilgili dataları düzenleyelim.

# %%
data["ORDERDATE"] = pd.to_datetime(data["ORDERDATE"]) 

print("Data içindeki son tarih:", data["ORDERDATE"].max())
print("Data içindeki ilk tarih:", data["ORDERDATE"].min())
#son tarihi referans alarak ilgili işlemlerimi yapıyorum
import datetime as dt
Now = dt.datetime(2005,5,31)
# Out:
# Data içindeki son tarih: 2005-05-31 00:00:00
# Data içindeki ilk tarih: 2003-01-06 00:00:00

# %%
data["recency_day"] = (Now - data["ORDERDATE"]).astype(str)
data[["recency_day", "B","C"]] = data["recency_day"].str.split(" ",expand = True)
data = data.drop(["B", "ORDERDATE","C"], axis=1)

# %%
data["recency_day"]  = data["recency_day"].astype(str)

# %% [markdown]
# * Tarih değişkeninin gün bazında değişimini merak ediyorum ve bunun için bir plot çizdirelim.

# %%
plt.figure(figsize=(30,10))
sns.set_style("darkgrid")
sns.distplot(data['recency_day'], bins=50,
            color = "#21DA4F")
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  \
# 0        10107               30      95.70                2  2871.00  Shipped
# 1        10121               34      81.35                5  2765.90  Shipped
# 2        10134               41      94.74                2  3884.34  Shipped
# 3        10145               45      83.26                6  3746.70  Shipped
# 4        10159               49     100.00               14  5205.27  Shipped
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...              CUSTOMERNAME  \
# 0       1         2     2003  Motorcycles  ...         Land of Toys Inc.
# 1       2         5     2003  Motorcycles  ...        Reims Collectables
# 2       3         7     2003  Motorcycles  ...           Lyon Souveniers
# 3       3         8     2003  Motorcycles  ...         Toys4GrownUps.com
# 4       4        10     2003  Motorcycles  ...  Corporate Gift Ideas Co.
#
#               PHONE                   ADDRESSLINE1           CITY POSTALCODE  \
# 0        2125557818        897 Long Airport Avenue            NYC      10022
# 1        26.47.1555             59 rue de l'Abbaye          Reims      51100
# 2  +33 1 46 62 7555  27 rue du Colonel Pierre Avia          Paris      75508
# 3        6265557265             78934 Hillside Dr.       Pasadena      90003
# 4        6505551386                7734 Strong St.  San Francisco        NaN
#
#   COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE recency_day
# 0     USA              Yu             Kwai    Small         827
# 1  France         Henriot             Paul    Small         755
# 2  France        Da Cunha           Daniel   Medium         700
# 3     USA           Young            Julie   Medium         645
# 4     USA           Brown            Julie   Medium         599
#
# [5 rows x 22 columns]

# %% [markdown]
# # Price analizi yapmadan önce gerekli temizlemeleri ve kontrolleri yapalım.
# Bu kontroller;
#
# 1. Negatif price değeri var mı?
# 2. Nan value'lar mevcutsa bunların doğru bir şekilde doldurulması.
# 3. İlgili Fiyat değerlerinin dağılımlarına bakalım. Normal dağılım bizim istediğimiz bir durumdur. Price normallik ve istatistiki testlerine bakalım

# %%
from scipy.stats import kurtosis
from scipy.stats import skew
print( 'excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis(data["SALES"]) ))
print( 'skewness of normal distribution (should be 0): {}'.format( skew(data["SALES"]) ))
# Out:
# excess kurtosis of normal distribution (should be 0): 1.7873782707746377
# skewness of normal distribution (should be 0): 1.160458972499323

# %% [markdown]
# # The values for asymmetry and kurtosis between -2 and +2 are considered acceptable in order to prove normal univariate distribution (George & Mallery, 2010).

# %%
temp  = pd.DataFrame(data["SALES"]).describe().T
temp.style.background_gradient(cmap="autumn_r")
#Herhangi bir negatif değerimiz yok. Bu kontrol analizimiz için oldukça önemli.
# Out:
# <style  type="text/css" >
#     #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col3 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col4 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col5 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col6 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col7 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }</style><table id="T_e23a4eb8_8b40_11ec_918a_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e23a4eb8_8b40_11ec_918a_086266b8e515level0_row0" class="row_heading level0 row0" >SALES</th>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col0" class="data row0 col0" >2823.000000</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col1" class="data row0 col1" >3553.889072</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col2" class="data row0 col2" >1841.865106</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col3" class="data row0 col3" >482.130000</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col4" class="data row0 col4" >2203.430000</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col5" class="data row0 col5" >3184.800000</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col6" class="data row0 col6" >4508.000000</td>
#                         <td id="T_e23a4eb8_8b40_11ec_918a_086266b8e515row0_col7" class="data row0 col7" >14082.800000</td>
#             </tr>
#     </tbody></table>

# %%
data['price_log'] = np.log(data['SALES']+1) 
#Bunun için daha farklı dönüşüm tipleri de bulunmaktadır.
fig, axarr = plt.subplots(2, 1, figsize=(24, 12))

sns.distplot(data["SALES"], bins=100,kde=True,ax=axarr[0])
axarr[0].set_title("Sales column graph", color="#f60000", size=20)
axarr[0].set_ylabel('Count', fontsize = 20, color="#2d242e")
axarr[0].set_xlabel('Sale', fontsize = 20, color="#2d242e")

sns.distplot(data['price_log'], bins=80, kde=True, ax=axarr[1])
axarr[1].set_title("Sales column after log transformation", color="#f60000", size=20)
axarr[1].set_ylabel('Count', fontsize = 20, color="#2d242e")
axarr[1].set_xlabel('Log_sale', fontsize = 20, color="#2d242e")
fig.show()
# Out:
# <ipython-input-128-b2d156c04177>:14: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
print( 'excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis(data["price_log"]) ))
print( 'skewness of normal distribution (should be 0): {}'.format( skew(data["price_log"]) ))
# Out:
# excess kurtosis of normal distribution (should be 0): -0.16961262504353725
# skewness of normal distribution (should be 0): -0.20150542936667845

# %% [markdown]
# # Sanki Daha Normal !
# # Sıradaki adım müşteri bazında toplam harcamaları, sıklık ve yenilik bazında gruplayalım.
# * Bir müşterinin birden çok alışverişi veya tarih değişkeni olabilir. Bu değerlerin daha sonra ortalamasını alıp nihai hedefimize ulaşabiliriz.

# %%
data_rfm = data.groupby(["CUSTOMERNAME"]).agg({
    "ORDERNUMBER" :"count",
    "SALES":  "sum",
    "recency_day":"min"})  # burada min değerini seçerek müşterinin en son ne zaman işlem yaptığı bilgisine ulaşıyorum.

data_rfm.rename(columns={'recency_day': 'Recency',
                   'ORDERNUMBER': 'Frequency',
                   'SALES': 'Monetary'}, inplace=True)

# %%
data_rfm.iloc[:5].style.background_gradient(cmap="Pastel1", low=0.50, high=1.0)
# Out:
# <style  type="text/css" >
#     #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row0_col0 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row0_col1 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row1_col0 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row1_col1 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row2_col0 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row2_col1 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row3_col0 {
#             background-color:  #fed9a6;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row3_col1 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row4_col0 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }    #T_e8e9af17_8b40_11ec_a8c9_086266b8e515row4_col1 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }</style><table id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frequency</th>        <th class="col_heading level0 col1" >Monetary</th>        <th class="col_heading level0 col2" >Recency</th>    </tr>    <tr>        <th class="index_name level0" >CUSTOMERNAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515level0_row0" class="row_heading level0 row0" >AV Stores, Co.</th>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row0_col1" class="data row0 col1" >157807.810000</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row0_col2" class="data row0 col2" >195</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515level0_row1" class="row_heading level0 row1" >Alpha Cognac</th>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row1_col0" class="data row1 col0" >20</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row1_col1" class="data row1 col1" >70488.440000</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row1_col2" class="data row1 col2" >570</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515level0_row2" class="row_heading level0 row2" >Amica Models & Co.</th>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row2_col0" class="data row2 col0" >26</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row2_col1" class="data row2 col1" >94117.260000</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row2_col2" class="data row2 col2" >264</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515level0_row3" class="row_heading level0 row3" >Anna's Decorations, Ltd</th>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row3_col0" class="data row3 col0" >46</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row3_col1" class="data row3 col1" >153996.130000</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row3_col2" class="data row3 col2" >131</td>
#             </tr>
#             <tr>
#                         <th id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515level0_row4" class="row_heading level0 row4" >Atelier graphique</th>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row4_col0" class="data row4 col0" >7</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row4_col1" class="data row4 col1" >24179.960000</td>
#                         <td id="T_e8e9af17_8b40_11ec_a8c9_086266b8e515row4_col2" class="data row4 col2" >187</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Lets make a RFM_score variable

# %%
data_rfm["Recency"] = data_rfm["Recency"] .astype(int)

# %%
zamansallık = pd.qcut(data_rfm["Recency"], q = 5, labels = range(1,6)).astype(str)
sıklık = pd.qcut(data_rfm["Frequency"], q = 5,    labels = range(1,6)).astype(str)
parasallık = pd.qcut(data_rfm["Monetary"], q = 5, labels = range(1,6)).astype(str)

data_rfm["R"] = zamansallık
data_rfm["F"] = sıklık
data_rfm["M"] = parasallık
data_rfm["RFM_score"] = data_rfm["R"]+ data_rfm["F"] +data_rfm["M"]
data_rfm.iloc[:5].style.background_gradient(cmap="Pastel1", low=0.50, high=1.0)
# Out:
# <style  type="text/css" >
#     #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col0 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col1 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col2 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col0 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col1 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col2 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col0 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col1 {
#             background-color:  #decbe4;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col2 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col0 {
#             background-color:  #fed9a6;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col1 {
#             background-color:  #ffffcc;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col2 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col0 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col1 {
#             background-color:  #b3cde3;
#             color:  #000000;
#         }    #T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col2 {
#             background-color:  #ccebc5;
#             color:  #000000;
#         }</style><table id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frequency</th>        <th class="col_heading level0 col1" >Monetary</th>        <th class="col_heading level0 col2" >Recency</th>        <th class="col_heading level0 col3" >R</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >M</th>        <th class="col_heading level0 col6" >RFM_score</th>    </tr>    <tr>        <th class="index_name level0" >CUSTOMERNAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515level0_row0" class="row_heading level0 row0" >AV Stores, Co.</th>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col1" class="data row0 col1" >157807.810000</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col2" class="data row0 col2" >195</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col4" class="data row0 col4" >5</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row0_col6" class="data row0 col6" >355</td>
#             </tr>
#             <tr>
#                         <th id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515level0_row1" class="row_heading level0 row1" >Alpha Cognac</th>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col0" class="data row1 col0" >20</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col1" class="data row1 col1" >70488.440000</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col2" class="data row1 col2" >570</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col3" class="data row1 col3" >5</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col4" class="data row1 col4" >2</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row1_col6" class="data row1 col6" >522</td>
#             </tr>
#             <tr>
#                         <th id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515level0_row2" class="row_heading level0 row2" >Amica Models & Co.</th>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col0" class="data row2 col0" >26</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col1" class="data row2 col1" >94117.260000</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col2" class="data row2 col2" >264</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col3" class="data row2 col3" >4</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col5" class="data row2 col5" >3</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row2_col6" class="data row2 col6" >433</td>
#             </tr>
#             <tr>
#                         <th id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515level0_row3" class="row_heading level0 row3" >Anna's Decorations, Ltd</th>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col0" class="data row3 col0" >46</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col1" class="data row3 col1" >153996.130000</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col2" class="data row3 col2" >131</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col4" class="data row3 col4" >5</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col5" class="data row3 col5" >5</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row3_col6" class="data row3 col6" >155</td>
#             </tr>
#             <tr>
#                         <th id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515level0_row4" class="row_heading level0 row4" >Atelier graphique</th>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col0" class="data row4 col0" >7</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col1" class="data row4 col1" >24179.960000</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col2" class="data row4 col2" >187</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col5" class="data row4 col5" >1</td>
#                         <td id="T_ea12e2c2_8b40_11ec_b48f_086266b8e515row4_col6" class="data row4 col6" >211</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # puanları genel olarak toplayıp ona göre aksiyon almak bizi yanıltabilir. O yüzden R, F ve m başlıklarını ayrı ayrı değerlendirmemiz gerektiğini düşünüyorum
# # RFM score'ları 511 ve 133 olan müşterilerin genel skorları aynıdır yani 7. Ancak bu iki müşteri grubu için aynı kampanyaları yapmak pek de verimli olmayabilir.
# # Strateji olarak;
# * örnek olarak rfm skorları şu şekilde olan müşteriler için ;
# * RFM_score = xx5  => Bu segmentasyondaki müşteriler için en pahalı ürünleri pazarlamaya çalış
# * RFM_score = 311 / 411 segmentinde olan müşteriler için agresif indirim kampanyaları düzenlenerek, ilgili müşteriler tekrar şirkete kazandırılabilir.

# %%
data_rfm[["Frequency","Monetary", "Recency"]] = data_rfm[["Frequency","Monetary", "Recency"]].astype(float)

# %%
R = pd.DataFrame(data_rfm["R"].value_counts())
M = pd.DataFrame(data_rfm["M"].value_counts())
F = pd.DataFrame(data_rfm["F"].value_counts())

# %%
fig = make_subplots(rows=1, cols=3, specs=[[{"type": "pie"}, {"type": "pie"},{"type": "pie"}]])


fig.add_trace(go.Pie(
     values=[19,18,19,17,19],
     labels=["1","2","3","4","5"],
     domain=dict(x=[0, 0.5]),
     name="GHG Emissions",
     title="Müşteri segmentasyonundaki R(recency) dağılımı"), 
     row=1, col=1)

fig.add_trace(go.Pie(
     values=[19,18,18,18,19],
     labels=["1","2","3","4","5"],
     domain=dict(x=[0, 0.5]),
     name="GHG Emissions",
     title="Müşteri segmentasyonundaki M(mondetory) dağılımı"), 
     row=1, col=2)

fig.add_trace(go.Pie(
     values=[20,18,19,17,18],
     labels=["1","2","3","4","5"],
     domain=dict(x=[0, 0.5]),
     name="GHG Emissions",
     title="Müşteri segmentasyonundaki F(frequency) dağılımı"), 
     row=1, col=3)

fig.show()
# Out:
# <div>                            <div id="5cea20ca-810b-4c05-aaa0-81ec217e28ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cea20ca-810b-4c05-aaa0-81ec217e28ee")) {                    Plotly.newPlot(                        "5cea20ca-810b-4c05-aaa0-81ec217e28ee",                        [{"domain": {"x": [0.0, 0.2888888888888889], "y": [0.0, 1.0]}, "labels": ["1", "2", "3", "4", "5"], "name": "GHG Emissions", "title": {"text": "M\u00fc\u015fteri segmentasyonundaki R(recency) da\u011f\u0131l\u0131m\u0131"}, "type": "pie", "values": [19, 18, 19, 17, 19]}, {"domain": {"x": [0.35555555555555557, 0.6444444444444445], "y": [0.0, 1.0]}, "labels": ["1", "2", "3", "4", "5"], "name": "GHG Emissions", "title": {"text": "M\u00fc\u015fteri segmentasyonundaki M(mondetory) da\u011f\u0131l\u0131m\u0131"}, "type": "pie", "values": [19, 18, 18, 18, 19]}, {"domain": {"x": [0.7111111111111111, 1.0], "y": [0.0, 1.0]}, "labels": ["1", "2", "3", "4", "5"], "name": "GHG Emissions", "title": {"text": "M\u00fc\u015fteri segmentasyonundaki F(frequency) da\u011f\u0131l\u0131m\u0131"}, "type": "pie", "values": [20, 18, 19, 17, 18]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0 ...

# %% [markdown]
# # Müşterilerin 3 kriter içinde yakın dağılım gösterdiğini söyleyebiliriz.
# # Kmeans algoritmasının çok daha verimli çalıştırmak için bazı düzenlemeler yapmalıyız. Bunun için;
#
# 1. İlgili değişkenlerin normal dağılıma sahip olması
# 2. Değişkenlerin aynı veya yakın ortalamada olması
# 3. Değişkenlerin aynı veya yakın varyans değerlerine sahip olması.

# %%
plt.style.use('ggplot')
fig, axarr = plt.subplots(1, 3, figsize=(32, 10))

axarr[0].hist(data_rfm['Recency'], bins=20, histtype= 'bar')
axarr[0].set_title("Recency")

axarr[1].hist(data_rfm['Frequency'], bins=20, histtype= 'stepfilled', color="#31CC57")
axarr[1].set_title("Frequency")

axarr[2].hist(data_rfm['Monetary'], bins=20,histtype= 'step', linewidth=3.2, color="#DE50DE")
axarr[2].set_title("Monetary")
plt.show()

# %% [markdown]
# 1. Satış fiyatlarını daha önce logaritmik dönüşüm ile normal dağılıma yaklaştırmıştık.
# 2. Aynı adımları diğer değişkenler için yapalım.

# %%
data_rfm["Recency"] = np.log(data_rfm["Recency"]+1)
data_rfm["Frequency"] = np.log(data_rfm["Frequency"]+1)
data_rfm["Monetary"] = np.log(data_rfm["Monetary"]+1)

# %%
plt.style.use('ggplot')
fig, axarr = plt.subplots(1, 3, figsize=(32, 10))

axarr[0].hist(data_rfm['Recency'], bins=20, histtype= 'bar')
axarr[0].set_title("Recency")

axarr[1].hist(data_rfm['Frequency'], bins=20, histtype= 'stepfilled', color="#31CC57")
axarr[1].set_title("Frequency")

axarr[2].hist(data_rfm["Monetary"], bins=20,histtype= 'step', linewidth=3.2, color="#DE50DE")
axarr[2].set_title("Monetary")
plt.show()

# %%
data_rfm.iloc[:5].style.background_gradient(cmap="autumn_r", low=0.50, high=1.0)
# Out:
# <style  type="text/css" >
#     #T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col0 {
#             background-color:  #ff6600;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col1 {
#             background-color:  #ff6600;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col2 {
#             background-color:  #ffb100;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col0 {
#             background-color:  #ff9800;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col1 {
#             background-color:  #ff9200;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col2 {
#             background-color:  #ff6600;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col0 {
#             background-color:  #ff8a00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col1 {
#             background-color:  #ff8200;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col2 {
#             background-color:  #ff9c00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col0 {
#             background-color:  #ff6b00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col1 {
#             background-color:  #ff6700;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col2 {
#             background-color:  #ffcc00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col0 {
#             background-color:  #ffcc00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col1 {
#             background-color:  #ffcc00;
#             color:  #000000;
#         }    #T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col2 {
#             background-color:  #ffb400;
#             color:  #000000;
#         }</style><table id="T_edc9b568_8b40_11ec_9a0c_086266b8e515" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Frequency</th>        <th class="col_heading level0 col1" >Monetary</th>        <th class="col_heading level0 col2" >Recency</th>        <th class="col_heading level0 col3" >R</th>        <th class="col_heading level0 col4" >F</th>        <th class="col_heading level0 col5" >M</th>        <th class="col_heading level0 col6" >RFM_score</th>    </tr>    <tr>        <th class="index_name level0" >CUSTOMERNAME</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_edc9b568_8b40_11ec_9a0c_086266b8e515level0_row0" class="row_heading level0 row0" >AV Stores, Co.</th>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col0" class="data row0 col0" >3.951244</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col1" class="data row0 col1" >11.969140</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col2" class="data row0 col2" >5.278115</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col4" class="data row0 col4" >5</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row0_col6" class="data row0 col6" >355</td>
#             </tr>
#             <tr>
#                         <th id="T_edc9b568_8b40_11ec_9a0c_086266b8e515level0_row1" class="row_heading level0 row1" >Alpha Cognac</th>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col0" class="data row1 col0" >3.044522</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col1" class="data row1 col1" >11.163218</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col2" class="data row1 col2" >6.347389</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col3" class="data row1 col3" >5</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col4" class="data row1 col4" >2</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col5" class="data row1 col5" >2</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row1_col6" class="data row1 col6" >522</td>
#             </tr>
#             <tr>
#                         <th id="T_edc9b568_8b40_11ec_9a0c_086266b8e515level0_row2" class="row_heading level0 row2" >Amica Models & Co.</th>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col0" class="data row2 col0" >3.295837</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col1" class="data row2 col1" >11.452307</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col2" class="data row2 col2" >5.579730</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col3" class="data row2 col3" >4</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col5" class="data row2 col5" >3</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row2_col6" class="data row2 col6" >433</td>
#             </tr>
#             <tr>
#                         <th id="T_edc9b568_8b40_11ec_9a0c_086266b8e515level0_row3" class="row_heading level0 row3" >Anna's Decorations, Ltd</th>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col0" class="data row3 col0" >3.850148</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col1" class="data row3 col1" >11.944689</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col2" class="data row3 col2" >4.882802</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col4" class="data row3 col4" >5</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col5" class="data row3 col5" >5</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row3_col6" class="data row3 col6" >155</td>
#             </tr>
#             <tr>
#                         <th id="T_edc9b568_8b40_11ec_9a0c_086266b8e515level0_row4" class="row_heading level0 row4" >Atelier graphique</th>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col0" class="data row4 col0" >2.079442</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col1" class="data row4 col1" >10.093321</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col2" class="data row4 col2" >5.236442</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col5" class="data row4 col5" >1</td>
#                         <td id="T_edc9b568_8b40_11ec_9a0c_086266b8e515row4_col6" class="data row4 col6" >211</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Why do we need scaling?
# Machine learning algorithm just sees number  if there is a vast difference in the range say few ranging in thousands and few ranging in the tens, and it makes the underlying assumption that higher ranging numbers have superiority of some sort. So these more significant number starts playing a more decisive role while training the model.

# %%
sc = StandardScaler()
scale_data =sc.fit_transform(data_rfm.iloc[:,:3])
scale_data = pd.DataFrame(scale_data, index = data_rfm.index, columns = ["Frequency", "Monetary", "Recency"])

# %% [markdown]
# 1. Değişken dağılımları normal dağılıma yaklaştırıldı
# 2. StandardScale ile ise ortalamaları 0 yaparak Kmeans algoritması iiçn uygun çalışma ortamı hazırladık.

# %% [markdown]
# # Görselleştirme için hazır bir kütüphane kullandım. Buradaki siyah çizgi en uygun number_of_cluster' a denk gelmektedir.
# * Bu nokta aynı zamanda grafikteki en yüksek açıya sahip noktadır. (Dirsek Kuralı)

# %%
print('Elbow Method to determine the number of clusters to be formed:')
Elbow_M = KElbowVisualizer(KMeans(), k=15)
plt.figure(figsize=(22,10))
Elbow_M.fit(scale_data)
Elbow_M.show()
# Out:
# Elbow Method to determine the number of clusters to be formed:

# %%
# En uygun sınıf sayısına göre kümelememizi yapalım

kmeans = KMeans(n_clusters = 5, random_state = 1)
kmeans.fit(scale_data)
cluster_labels = kmeans.labels_
data_rfm = data_rfm.assign(Cluster=cluster_labels)
data_rfm.head()
# Out:
#                          Frequency   Monetary   Recency  R  F  M RFM_score  \
# CUSTOMERNAME
# AV Stores, Co.            3.951244  11.969140  5.278115  3  5  5       355
# Alpha Cognac              3.044522  11.163218  6.347389  5  2  2       522
# Amica Models & Co.        3.295837  11.452307  5.579730  4  3  3       433
# Anna's Decorations, Ltd   3.850148  11.944689  4.882802  1  5  5       155
# Atelier graphique         2.079442  10.093321  5.236442  2  1  1       211
#
#                          Cluster
# CUSTOMERNAME
# AV Stores, Co.                 0
# Alpha Cognac                   4
# Amica Models & Co.             4
# Anna's Decorations, Ltd        0
# Atelier graphique              1

# %%
data_rfm["Recency"] = np.exp(data_rfm["Recency"])
data_rfm["Frequency"] = np.exp(data_rfm["Frequency"])
data_rfm["Monetary"] =np.exp(data_rfm["Monetary"])

# %%
data_rfm[["Frequency","Monetary", "Recency"]] = data_rfm[["Frequency","Monetary", "Recency"]].astype(float)
grouped = data_rfm.groupby(['Cluster'])

# Calculate average RFM values and segment sizes per cluster value
grouped.agg({
    'Recency': ['mean','std'],
    'Frequency': ['mean','std'],
    'Monetary': ['mean', 'count']
  }).round(1)
# Out:
#         Recency        Frequency        Monetary
#            mean    std      mean   std      mean count
# Cluster
# 0         196.9   94.0      38.8   7.7  135498.7    30
# 1         343.5  164.3      12.0   3.6   36909.3    13
# 2          52.5   72.8     220.5  55.9  783577.1     2
# 3           5.0    6.7      38.2  12.2  131759.5     4
# 4         241.7  114.7      23.3   3.8   78924.4    43

# %%
data_dim = data.merge(data_rfm[['Cluster']], on="CUSTOMERNAME", how="left")

# %% [markdown]
# # We will make it numeric for dimension reduction.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
label_data = ["PRODUCTCODE","CUSTOMERNAME","PHONE","ADDRESSLINE1","CITY",
              "POSTALCODE","CONTACTLASTNAME","COUNTRY","CONTACTLASTNAME",
              "CONTACTFIRSTNAME","DEALSIZE","recency_day","STATUS","PRODUCTLINE"]
for i in label_data:
    data[i] =  data[i].astype(str)
    data[i] = le.fit_transform(data[i].values)
    
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  STATUS  \
# 0        10107               30      95.70                2  2871.00       5
# 1        10121               34      81.35                5  2765.90       5
# 2        10134               41      94.74                2  3884.34       5
# 3        10145               45      83.26                6  3746.70       5
# 4        10159               49     100.00               14  5205.27       5
#
#    QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  PHONE  ADDRESSLINE1  CITY  \
# 0       1         2     2003            1  ...     48            57    42
# 1       2         5     2003            1  ...     54            40    56
# 2       3         7     2003            1  ...     16            21    52
# 3       3         8     2003            1  ...     76            54    53
# 4       4        10     2003            1  ...     77            51    59
#
#    POSTALCODE  COUNTRY  CONTACTLASTNAME  CONTACTFIRSTNAME  DEALSIZE  \
# 0           0       18               74                36         2
# 1          27        6               21                54         2
# 2          41        6                9                11         1
# 3          49       18               73                31         1
# 4          73       18               75                31         1
#
#    recency_day  price_log
# 0          236   7.962764
# 1          220   7.925483
# 2          209   8.264966
# 3          198   8.228898
# 4          181   8.557619
#
# [5 rows x 23 columns]

# %%
#PCA 
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
X_pca = pipe.fit_transform(data)

#t-sne
tsne = TSNE()
pipe = Pipeline([("scaler", StandardScaler()), ('tsne', tsne)])
X_tsne = pipe.fit_transform(data)

# %%
plt.style.use('ggplot')
fig, axarr = plt.subplots(1, 2, figsize=(32, 10))

fig.suptitle("Dimensionality Reduction techniques", color ="red", size = 28)
axarr[0].scatter(X_pca[:,0], X_pca[:,1],alpha=0.8,edgecolors="#F50D2F" ,linewidths=0.8, c="#49BAF1")
axarr[0].set_title("Ham data işlenmeden PCA uygulanması" ,color="red")
axarr[0].set_ylabel("2.düzlem", color ="black")
axarr[0].set_xlabel("1.düzlem", color ="black")
axarr[0].set_yticklabels([])
axarr[0].set_xticklabels([])
axarr[0].grid(False)

axarr[1].scatter(X_tsne[:,0], X_tsne[:,1],alpha=0.8,edgecolors="#F50D2F" ,linewidths=0.8, c="#49BAF1")
axarr[1].set_title("Ham data işlenmeden t-SNE uygulanması" ,color="red")
axarr[1].set_ylabel("2.düzlem", color ="black")
axarr[1].set_xlabel("1.düzlem", color ="black")
axarr[1].set_yticklabels([])
axarr[1].set_xticklabels([])
axarr[1].grid(False)
fig.show()
# Out:
# <ipython-input-123-2245ccfe9168>:20: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # son olarak ham data ile cluster kolonunu birleştirerek bir görselleştirme yapalım.

# %%
label_data = ["PRODUCTCODE","CUSTOMERNAME","PHONE","ADDRESSLINE1","CITY",
              "POSTALCODE","CONTACTLASTNAME","COUNTRY","CONTACTLASTNAME",
              "CONTACTFIRSTNAME","DEALSIZE","recency_day","STATUS","PRODUCTLINE"]
for i in label_data:
    data_dim[i] =  data_dim[i].astype(str)
    data_dim[i] = le.fit_transform(data[i].values)
    
y = data_dim["Cluster"]

#PCA 
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
X_pca = pipe.fit_transform(data_dim.iloc[:,:23])

pipe = Pipeline([("scaler", StandardScaler()), ('tsne', tsne)])
X_tsne = pipe.fit_transform(data_dim.iloc[:,:23])

print(X_tsne.shape)
# Out:
# (2823, 2)

# %%
plt.style.use('ggplot')
fig, axarr = plt.subplots(1, 2, figsize=(32, 10))

fig.suptitle("Dimensionality Reduction techniques", color ="red", size = 28)
axarr[0].scatter(X_pca[:,0], X_pca[:,1],alpha=0.8,edgecolors="#F50D2F" ,linewidths=0.8, c=y)
axarr[0].set_title("Ham data işlenmeden PCA uygulanması" ,color="red")
axarr[0].set_ylabel("2.düzlem", color ="black")
axarr[0].set_xlabel("1.düzlem", color ="black")
axarr[0].set_yticklabels([])
axarr[0].set_xticklabels([])
axarr[0].grid(False)

axarr[1].scatter(X_tsne[:,0], X_tsne[:,1],alpha=0.8,edgecolors="#F50D2F" ,linewidths=0.8, c=y)
axarr[1].set_title("Ham data işlenmeden t-SNE uygulanması" ,color="red")
axarr[1].set_ylabel("2.düzlem", color ="black")
axarr[1].set_xlabel("1.düzlem", color ="black")
axarr[1].set_yticklabels([])
axarr[1].set_xticklabels([])
axarr[1].grid(False)
fig.show()
# Out:
# <ipython-input-126-20e479d2b5bd>:20: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # Sonuç;
# 1. Rfm analizi sonucu müşteri gruplarının birbirinden farklı olduğunu ve oluşan kümelere göre aksiyon almamız gerektiğini gördük.
# 2. oluşturduğumuz sıklık, yenilik ve parasallık kavramları ile bu ayrımı yaparak ilgili dataseti(rfm_data) oluşturduk.
# 3. Dirsek kuralını kullanarak en uygun küme sayısı seçildi.
# 4. Datanın önce ve sonrası PCA ve TSNE uygulanarak görselleştirildi. 2. kısımda cluster değişkenine göre renklendirerek anlamlı sonuç arandı, ancak bulunamadı.

# %% [markdown]
# # References:
# * https://www.kaggle.com/alekhyabotta/customer-segmentation
# * https://www.kaggle.com/yugagrawal95/k-means-clustering-using-seaborn-visualization
# * https://medium.com/@krglnahmetcan/rfm-analizi-ile-m%C3%BC%C5%9Fteri-segmentasyonu-b3c7233b4243
# * https://towardsdatascience.com/feature-extraction-using-principal-component-analysis-a-simplified-visual-demo-e5592ced100a
# * https://www.scikit-yb.org/en/latest/api/cluster/elbow.html
# * https://towardsdatascience.com/all-about-feature-scaling-bcc0ad75cb35#:~:text=Feature%20scaling%20is%20essential%20for,that%20calculate%20distances%20between%20data.&text=Since%20the%20range%20of%20values,not%20work%20correctly%20without%20normalization.
# * AND OF COURSE https://stackoverflow.com/
